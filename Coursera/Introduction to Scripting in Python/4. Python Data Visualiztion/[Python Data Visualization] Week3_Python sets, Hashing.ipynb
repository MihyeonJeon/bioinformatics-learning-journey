# %% [markdown]
# ### [Python Sets]
#
# * A set is similar to list and tuples but they don't have a specified order, nor can they contain duplicates.
# * Empty curly braces is actually an empty dictionary in Python.
# * If you want to create an empty set, you need to write 'set()'.

# %%
"""
Using sets.
"""

print("Set Literals")
print("============")

numbers = {3, 2, 1, 4}
print(numbers)

letters = {"a", "b", "a", "c", "b"}
print(letters)

empty = {}
print(empty, type(empty))

empty2 = set()
print(empty2, type(empty2))

set1 = set([3, 1, 1, 3, 6, 5])
print(set1)

set2 = set(range(5))
print(set2)

print("")
print("Adding/Removing Elements")
print("========================")

set1.add(10)
print(set1)

element = set1.pop()
print(element)
print(set1)

set1.discard(3)
print(set1)

print("")
print("Set Iteration")
print("=============")

for item in letters:
    print(item)
# Out:
# Set Literals
# ============
# {1, 2, 3, 4}
# {'b', 'c', 'a'}
# {} <class 'dict'>
# set() <class 'set'>
# {1, 3, 5, 6}
# {0, 1, 2, 3, 4}
#
# Adding/Removing Elements
# ========================
# {1, 3, 5, 6, 10}
# 1
# {3, 5, 6, 10}
# {5, 6, 10}
#
# Set Iteration
# =============
# b
# c
# a

# %% [markdown]
# ### [Hashing]
#
# #### * Sets
# * With a list, you would have to seach the entire list to determine whether or not a particular element is contained in the list so the time to test for membership in a list can be proportional to the size of the list.
# * With a set, the time is relatively constant no matter how many times are in the set because of a hash table.
# > It means when the collection get large, the fast membership operations can be a big win.
#
# #### * Hashing
# * A hash table is a table in which you look things up directly by index into that table.
# * In order to use such a table, you need to be able to determine a consistent index for an arbitrary item (such as a string) that you want to store in the table.
# * This is where hashing comes in.  Python includes a set of hash functions, one for each hashable type.
# * These hash functions have multiple important properties.
# > 1. The hash function will always return the same hash for objects that have the same value.
# > 2. The hash function will distribute the hash values across the possible space. (important for efficiency, not for correctness).
#
# * A good hash function avoids collisions as much as possible. (Collision happens when two different objects have the same index into the hasy table.)
#
# #### * Hashability
#
# * Only immutable objects can successfully be stored in a hash table, and therefore a Python set.
# * A type is hashable if there is a hash function that can be used for the immutable builtin types.
#
# #### * Dictionaries
#
# * Python dictionaries also use hash tables internally. You cannot have duplicate keys in a dictionary. You can use a hash table and get the same performance benefits.

# %% [markdown]
# ### [Analyzing the Efficiency of Your code]
#
# * Using code that's correct and understandable and that others can work with easily is important.
# * However, as you prgress, the efficiency is also important.
# * It means how fast your code runs on a problem of a particular size.
# > * [Algorithmic efficiency](https://en.wikipedia.org/wiki/Algorithmic_efficiency)
# > * [TimeComplexity](https://wiki.python.org/moin/TimeComplexity)

# %% [markdown]
# ### [Comparing Two Methods for joining CSV Files]

# %%
PATH = '/content/drive/MyDrive/etc/'

# %%
"""
Some sample code illustrating the speed of the "in" operator for lists vs. dictionaries in Python
See https://wiki.python.org/moin/TimeComplexity for more details
"""

import time
import random
import csv


def read_csv_file(file_name):
    """
    Given a CSV file, read the data into a nested list
    Input: String corresponding to comma-separated  CSV file
    Output: Nested list consisting of the fields in the CSV file
    """ 
       
    with open(file_name, newline='') as csv_file:       # don't need to explicitly close the file now
        csv_table = []
        csv_reader = csv.reader(csv_file, delimiter=',')
        for row in csv_reader:
            csv_table.append(row)
    return csv_table



CANCER_RISK_FIPS_COL = 2
CENTER_FIPS_COL = 0


def test_CSV_join_efficiency(cancer_csv_file, center_csv_file):
    """
    Extract lists of FIPS codes from cancer-risk data set and county center data set
    Measure running time to determine whether FIPS codes in cancer-risk set are in county center set
    """
    
    # Read in both CSV files
    risk_table = read_csv_file(cancer_csv_file)
    risk_FIPS_list = [risk_table[idx][CANCER_RISK_FIPS_COL] for idx in range(len(risk_table))]
    print("Read", len(risk_FIPS_list), "cancer-risk FIPS codes")
       
    center_table = read_csv_file(center_csv_file)
    center_FIPS_list = [center_table[idx][CENTER_FIPS_COL] for idx in range(len(center_table))]
    print("Read", len(center_FIPS_list), "county center FIPS codes")
    
    start_time = time.time()
    for code in risk_FIPS_list:
        if code in center_FIPS_list:      
            pass
    end_time = time.time()
    print("Checked for FIPS membership using list in", end_time-start_time, "seconds")
    
    
    center_FIPS_dict = {code : True for code in center_FIPS_list}
    start_time = time.time()
    for code in risk_FIPS_list:
        if code in center_FIPS_dict:  
            pass
    end_time = time.time()
    print("Checked for FIPS membership using dict in", end_time-start_time, "seconds")


test_CSV_join_efficiency(PATH+"cancer_risk_trimmed_solution.csv", PATH+"USA_Counties_with_FIPS_and_centers.csv")
# Out:
# Read 3276 cancer-risk FIPS codes
# Read 3143 county center FIPS codes
# Checked for FIPS membership using list in 0.09780097007751465 seconds
# Checked for FIPS membership using dict in 0.0005114078521728516 seconds

# %%
# Code that test the efficiency of "in" operator on larger examples

TEST_SIZE = 20000
TEST_STRIDE = 3

def test_membership_efficiency():
    """
    Test the efficiency of the "in" operator on list/dictionaries of larger size
    """
    test_list = list(range(0, TEST_SIZE, TEST_STRIDE))  # Convert range() to list, membership in range is fast
    test_dict = {idx : True for idx in test_list}
    
    print()

    # Code to test efficiency of "in" for lists
    start_time = time.time()
    for idx in range(TEST_SIZE):
        if idx in test_list:      # "in" operation iterates through entire list to check membership
            pass
    end_time = time.time()
    print("Total time for", TEST_SIZE, "membership test for list is", end_time - start_time, "seconds")
    
    # Code to test efficiency of "in" for dicts
    start_time = time.time()
    for idx in range(TEST_SIZE):
        if idx in test_dict:      # "in" operations does NOT iterate through dictionary to check membership
            pass
    end_time = time.time()
    print("Total time for", TEST_SIZE, "membership test for dict is", end_time - start_time, "seconds")
    
test_membership_efficiency()
# Out:
# Total time for 20000 membership test for list is 1.5725421905517578 seconds
# Total time for 20000 membership test for dict is 0.0013015270233154297 seconds

# %% [markdown]
# ---
# ## [Practice Project: Reconciling Cancer-Risk Data with the USA Map]
#
# 1. Merge two county-level data sets by common FIPS code
# 2. Write a script that reads both CSV files, merges by FIPS code, outputs to a CSV file
# 3. Investigate discrepancies in the two sets of FIPS code

# %%
"""
Week 3 practice project template for Python Data Visualization
Read two CSV files and join the resulting tables based on shared FIPS codes
Analyze both data sources for anamolous FIPS codes
"""

import csv



#########################################################
# Provided code for week 3

def print_table(table):
    """
    Echo a nested list to the console
    """
    for row in table:
        print(row)


def read_csv_file(file_name):
    """
    Given a CSV file, read the data into a nested list
    Input: String corresponding to comma-separated  CSV file
    Output: Nested list consisting of the fields in the CSV file
    """
       
    with open(file_name, newline='') as csv_file:       # don't need to explicitly close the file now
        csv_table = []
        csv_reader = csv.reader(csv_file, delimiter=',')
        for row in csv_reader:
            csv_table.append(row)
    return csv_table



def write_csv_file(csv_table, file_name):
    """
    Input: Nested list csv_table and a string file_name
    Action: Write fields in csv_table into a comma-separated CSV file with the name file_name
    """
    
    with open(file_name, 'w', newline='') as csv_file:
        csv_writer = csv.writer(csv_file, delimiter=',', quoting=csv.QUOTE_MINIMAL)
        for row in csv_table:
            csv_writer.writerow(row)



# Part 1 - function that creates a dictionary from a table

def make_dict(table, key_col):
    """
    Given a 2D table (list of lists) and a column index key_col,
    return a dictionary whose keys are entries of specified column
    and whose values are lists consisting of the remaining row entries
    """
    return_dict = {}
    for row in table:
        temp_list = row.copy()
        temp_list.remove(row[key_col])
        return_dict[row[key_col]] = temp_list
    return return_dict




def test_make_dict():
    """
    Some tests for make_dict()
    """
    table1 = [[1, 2], [3, 4], [5, 6]]
    print(make_dict(table1, 0))
    print(make_dict(table1, 1))
    table2 = [[1, 2, 3], [2, 4, 6], [3, 6, 9]]
    print(make_dict(table2, 1))
    print(make_dict(table2, 2))
    
test_make_dict()



# Part 2 - script for merging the CSV files

CANCER_RISK_FIPS_COL = 2
CENTER_FIPS_COL = 0

def merge_csv_files(cancer_csv_file, center_csv_file, joined_csv_file):
    """
    Read two specified CSV files as tables
    Join the these tables by shared FIPS codes
    Write the resulting joined table as the specified file
    Analyze for problematic FIPS codes
    """
    # Read in both CSV files
    cancer_data = read_csv_file(cancer_csv_file) #3276
    center_data = read_csv_file(center_csv_file) #3143 결론은 3140건

    print("Read risk table of lengh", len(cancer_data))
    print("Read center table of lengh", len(center_data))

    center_dict = make_dict(center_data, CENTER_FIPS_COL)
    
    # Compute joined table, print warning about cancer-risk FIPS codes that are not in USA map
    joined_table = []
    for row in cancer_data:
        FIPS_code = row[2]
        if FIPS_code in center_dict:
            joined_table.append(row+center_dict[FIPS_code])
        else:
            print("Row", row, "in cancer risk table not present in USA map")


    # Write joined table
    print("Wrote joined table of length", len(joined_table))
    write_csv_file(joined_table, joined_csv_file)
    
    # Print warning about FIPS codes in USA map that are missing from cancer risk data
    print()
    risk_code = [cancer_data[idx][2] for idx in range(len(cancer_data))]
    for center_code in center_dict:
        print("Code", center_code, "in center table not present in cancer risk table")


merge_csv_files(PATH+"cancer_risk_trimmed_solution.csv", PATH+"USA_Counties_with_FIPS_and_centers.csv", "cancer_risk_joined.csv")




## Part 3 - Explanation for anomalous FIPS codes

## https://www1.udel.edu/johnmack/frec682/fips_codes.html
##
## Output anamolies for cancer risk data
## Puerto Rico, Virgin Island, Statewide, Nationwide - FIPS codes are all not present on USA map
## One specific county (Clifton Forge, VA - 51560) is also not present in USA map.
## According URL above, Clifton Forge was merged with another VA county prior to 2001
##
## Output anamolies for USA map
## State_Line, separator - FIPS codes are all not present in cancer-risk data
## One specific county (Broomfield County - 08014) is also not present in cancer-risk data
## Accoring to URL above, Broomfield County was created in 2001
##
## Implies cancer risk FIPS codes were defined prior to 2001, the USA map FIPS codes were defined after 2001
# Out:
# {1: [2], 3: [4], 5: [6]}
# {2: [1], 4: [3], 6: [5]}
# {2: [1, 3], 4: [2, 6], 6: [3, 9]}
# {3: [1, 2], 6: [2, 4], 9: [3, 6]}
# Read risk table of lengh 3276
# Read center table of lengh 3143
# Row ['CA', 'Statewide', '06000', '33871648', '7.7E-05'] in cancer risk table not present in USA map
# Row ['DC', 'Statewide', '11000', '572059', '7.7E-05'] in cancer risk table not present in USA map
# Row ['NY', 'Statewide', '36000', '18976457', '7.2E-05'] in cancer risk table not present in USA map
# Row ['MD', 'Statewide', '24000', '5296486', '5.7E-05'] in cancer risk table not present in USA map
# Row ['NJ', 'Statewide', '34000', '8414350', '5.6E-05'] in cancer risk table not present in USA map
# Row ['AZ', 'Statewide', '04000', '5130632', '5.5E-05'] in cancer risk table not present in USA map
# Row ['OR', 'Statewide', '41000', '3421399', '5.5E-05'] in cancer risk table not present in USA map
# Row ['CT', 'Statewide', '09000', '3405565', '5.3E-05'] in cancer risk table not present in USA map
# Row ['GA', 'Statewide', '13000', '8186453', '5.3E-05'] in cancer risk table not present in USA map
# Row ['US', 'Nationwide', '-', '285339128', '5.0E-05'] in cancer risk table not present in USA map
# Row ['MA', 'Statewide', '25000', '6349097', '5.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'San Juan', '72127', '434374', '5.0E-05'] in cancer risk table not present in USA map
# Row ['AL', 'Statewide', '01000', '4447100', '4.9E-05'] in cancer risk table not present in USA map
# Row ['IL', 'Statewide', '17000', '12419293', '4.8E-05'] in cancer risk table not present in USA map
# Row ['CO', 'Statewide', '08000', '4301261', '4.7E-05'] in cancer risk table not present in USA map
# Row ['FL', 'Statewide', '12000', '15982378', '4.6E-05'] in cancer risk table not present in USA map
# Row ['TN', 'Statewide', '47000', '5689283', '4.6E-05'] in cancer risk table not present in USA map
# Row ['VA', 'Statewide', '51000', '7078515', '4.6E-05'] in cancer risk table not present in USA map
# Row ['LA', 'Statewide', '22000', '4468976', '4.5E-05'] in cancer risk table not present in USA map
# Row ['MI', 'Statewide', '26000', '9938444', '4.4E-05'] in cancer risk table not present in USA map
# Row ['TX', 'Statewide', '48000', '20851820', '4.4E-05'] in cancer risk table not present in USA map
# Row ['WI', 'Statewide', '55000', '5363675', '4.4E-05'] in cancer risk table not present in USA map
# Row ['DE', 'Statewide', '10000', '783600', '4.3E-05'] in cancer risk table not present in USA map
# Row ['MO', 'Statewide', '29000', '5595211', '4.3E-05'] in cancer risk table not present in USA map
# Row ['PA', 'Statewide', '42000', '12281054', '4.3E-05'] in cancer risk table not present in USA map
# Row ['WA', 'Statewide', '53000', '5894121', '4.3E-05'] in cancer risk table not present in USA map
# Row ['MS', 'Statewide', '28000', '2844658', '4.2E-05'] in cancer risk table not present in USA map
# Row ['NV', 'Statewide', '32000', '1998257', '4.2E-05'] in cancer risk table not present in USA map
# Row ['SC', 'Statewide', '45000', '4012012', '4.2E-05'] in cancer risk table not present in USA map
# Row ['NH', 'Statewide', '33000', '1235786', '4.1E-05'] in cancer risk table not present in USA map
# Row ['OH', 'Statewide', '39000', '11353140', '4.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Catano', '72033', '30071', '4.1E-05'] in cancer risk table not present in USA map
# Row ['AR', 'Statewide', '05000', '2673400', '4.0E-05'] in cancer risk table not present in USA map
# Row ['NE', 'Statewide', '31000', '1711263', '4.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Bayamon', '72021', '224044', '4.0E-05'] in cancer risk table not present in USA map
# Row ['KY', 'Statewide', '21000', '4041769', '3.9E-05'] in cancer risk table not present in USA map
# Row ['NC', 'Statewide', '37000', '8049313', '3.9E-05'] in cancer risk table not present in USA map
# Row ['RI', 'Statewide', '44000', '1048319', '3.9E-05'] in cancer risk table not present in USA map
# Row ['MN', 'Statewide', '27000', '4919479', '3.8E-05'] in cancer risk table not present in USA map
# Row ['OK', 'Statewide', '40000', '3450654', '3.8E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Guaynabo', '72061', '100053', '3.8E-05'] in cancer risk table not present in USA map
# Row ['KS', 'Statewide', '20000', '2688418', '3.7E-05'] in cancer risk table not present in USA map
# Row ['IN', 'Statewide', '18000', '6080485', '3.6E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Carolina', '72031', '186076', '3.6E-05'] in cancer risk table not present in USA map
# Row ['IA', 'Statewide', '19000', '2926324', '3.5E-05'] in cancer risk table not present in USA map
# Row ['UT', 'Statewide', '49000', '2233169', '3.5E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Toa Baja', '72137', '94085', '3.4E-05'] in cancer risk table not present in USA map
# Row ['WV', 'Statewide', '54000', '1808344', '3.3E-05'] in cancer risk table not present in USA map
# Row ['ID', 'Statewide', '16000', '1293953', '3.2E-05'] in cancer risk table not present in USA map
# Row ['ME', 'Statewide', '23000', '1274923', '3.2E-05'] in cancer risk table not present in USA map
# Row ['AK', 'Statewide', '02000', '626932', '3.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Caguas', '72025', '140502', '3.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Statewide', '72000', '3808610', '2.9E-05'] in cancer risk table not present in USA map
# Row ['NM', 'Statewide', '35000', '1819046', '2.8E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Barceloneta', '72017', '22322', '2.8E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Toa Alta', '72135', '63929', '2.8E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Trujillo Alto', '72139', '75728', '2.8E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Dorado', '72051', '34017', '2.7E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Ponce', '72113', '186475', '2.7E-05'] in cancer risk table not present in USA map
# Row ['HI', 'Statewide', '15000', '1211537', '2.6E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Naranjito', '72105', '29709', '2.6E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Vega Alta', '72143', '37910', '2.6E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Aguadilla', '72005', '64685', '2.5E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Arecibo', '72013', '100131', '2.5E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Corozal', '72047', '36867', '2.5E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Mayaguez', '72097', '98434', '2.5E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Vega Baja', '72145', '61929', '2.5E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Aguas Buenas', '72007', '29032', '2.4E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Cidra', '72041', '42753', '2.4E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Comerio', '72045', '20002', '2.4E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Gurabo', '72063', '36743', '2.4E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Loiza', '72087', '32537', '2.4E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Manati', '72091', '45409', '2.4E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Morovis', '72101', '29965', '2.4E-05'] in cancer risk table not present in USA map
# Row ['VT', 'Statewide', '50000', '608827', '2.3E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Aibonito', '72009', '26493', '2.3E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Anasco', '72011', '28348', '2.3E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Barranquitas', '72019', '28909', '2.3E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Canovanas', '72029', '43335', '2.3E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Cayey', '72035', '47370', '2.3E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Coamo', '72043', '37597', '2.3E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Culebra', '72049', '1868', '2.3E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Florida', '72054', '12367', '2.3E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Hormigueros', '72067', '16614', '2.3E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Juncos', '72077', '36452', '2.3E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Aguada', '72003', '42042', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Camuy', '72027', '35244', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Hatillo', '72065', '38925', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Humacao', '72069', '59035', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Isabela', '72071', '44444', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Las Piedras', '72085', '34485', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Moca', '72099', '39697', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Penuelas', '72111', '26719', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Quebradillas', '72115', '25450', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Rio Grande', '72119', '52362', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Salinas', '72123', '31113', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'San Lorenzo', '72129', '40997', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'San Sebastian', '72131', '44204', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Utuado', '72141', '35336', '2.2E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Villalba', '72149', '27913', '2.2E-05'] in cancer risk table not present in USA map
# Row ['MT', 'Statewide', '30000', '902195', '2.1E-05'] in cancer risk table not present in USA map
# Row ['SD', 'Statewide', '46000', '754844', '2.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Ceiba', '72037', '18004', '2.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Ciales', '72039', '19811', '2.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Fajardo', '72053', '40712', '2.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Guayama', '72057', '44301', '2.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Guayanilla', '72059', '23072', '2.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Jayuya', '72073', '17318', '2.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Juana Diaz', '72075', '50531', '2.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Lares', '72081', '34415', '2.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Sabana Grande', '72121', '25935', '2.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Yabucoa', '72151', '39246', '2.1E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Yauco', '72153', '46384', '2.1E-05'] in cancer risk table not present in USA map
# Row ['ND', 'Statewide', '38000', '642200', '2.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Adjuntas', '72001', '19143', '2.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Cabo Rojo', '72023', '46911', '2.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Lajas', '72079', '26261', '2.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Luquillo', '72089', '19817', '2.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Naguabo', '72103', '23753', '2.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Orocovis', '72107', '23844', '2.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Rincon', '72117', '14767', '2.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'San German', '72125', '37105', '2.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Santa Isabel', '72133', '21665', '2.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Vieques', '72147', '9106', '2.0E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Las Marias', '72083', '11061', '1.9E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Maricao', '72093', '6449', '1.9E-05'] in cancer risk table not present in USA map
# Row ['VA', 'Clifton Forge', '51560', '4289', '1.8E-05'] in cancer risk table not present in USA map
# Row ['WY', 'Statewide', '56000', '493782', '1.8E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Arroyo', '72015', '19117', '1.8E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Guanica', '72055', '21888', '1.8E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Maunabo', '72095', '12741', '1.8E-05'] in cancer risk table not present in USA map
# Row ['PR', 'Patillas', '72109', '20152', '1.8E-05'] in cancer risk table not present in USA map
# Row ['VI', 'St. Thomas', '78030', '51181', '1.7E-05'] in cancer risk table not present in USA map
# Row ['VI', 'Statewide', '78000', '108612', '1.6E-05'] in cancer risk table not present in USA map
# Row ['VI', 'St. Croix', '78010', '53234', '1.6E-05'] in cancer risk table not present in USA map
# Row ['VI', 'St. John', '78020', '4197', '7.4E-06'] in cancer risk table not present in USA map
# Wrote joined table of length 3140
#
# Code 02185 in center table not present in cancer risk table
# Code 02188 in center table not present in cancer risk table
# Code 02130 in center table not present in cancer risk table
# Code 02201 in center table not present in cancer risk table
# Code 02280 in center table not present in cancer risk table
# Code 02220 in center table not present in cancer risk table
# Code 02100 in center table not present in cancer risk table
# Code 02110 in center table not present in cancer risk table
# Code 02232 in center table not present in cancer risk table
# Code 02282 in center table not present in cancer risk table
# Code 02016 in center table not present in cancer risk table
# Code 02013 in center table not present in cancer risk table
# Code 02150 in center table not present in cancer risk table
# Code 02060 in center table not present in cancer risk table
# Code 02070 in center table not present in cancer risk table
# Code 02164 in center table not present in cancer risk table
# Code 02122 in center table not present in cancer risk table
# Code 02020 in center table not present in cancer risk table
# Code 02261 in center table not present in cancer risk table
# Code 02170 in center table not present in cancer risk table
# Code 02240 in center table not present in cancer risk table
# Code 02090 in center table not present in cancer risk table
# Code 02068 in center table not present in cancer risk table
# Code 02050 in center table not present in cancer risk table
# Code 02270 in center table not present in cancer risk table
# Code 02180 in center table not present in cancer risk table
# Code 02290 in center table not present in cancer risk table
# Code 01069 in center table not present in cancer risk table
# Code 01067 in center table not present in cancer risk table
# Code 01061 in center table not present in cancer risk table
# Code 01045 in center table not present in cancer risk table
# Code 01031 in center table not present in cancer risk table
# Code 01039 in center table not present in cancer risk table
# Code 01097 in center table not present in cancer risk table
# Code 01003 in center table not present in cancer risk table
# Code 01053 in center table not present in cancer risk table
# Code 01035 in center table not present in cancer risk table
# Code 01129 in center table not present in cancer risk table
# Code 01023 in center table not present in cancer risk table
# Code 01025 in center table not present in cancer risk table
# Code 01099 in center table not present in cancer risk table
# Code 01131 in center table not present in cancer risk table
# Code 01013 in center table not present in cancer risk table
# Code 01041 in center table not present in cancer risk table
# Code 01109 in center table not present in cancer risk table
# Code 01011 in center table not present in cancer risk table
# Code 01087 in center table not present in cancer risk table
# Code 01085 in center table not present in cancer risk table
# Code 01101 in center table not present in cancer risk table
# Code 01051 in center table not present in cancer risk table
# Code 01001 in center table not present in cancer risk table
# Code 01047 in center table not present in cancer risk table
# Code 01091 in center table not present in cancer risk table
# Code 01119 in center table not present in cancer risk table
# Code 01105 in center table not present in cancer risk table
# Code 01021 in center table not present in cancer risk table
# Code 01037 in center table not present in cancer risk table
# Code 01123 in center table not present in cancer risk table
# Code 01027 in center table not present in cancer risk table
# Code 01121 in center table not present in cancer risk table
# Code 01117 in center table not present in cancer risk table
# Code 01007 in center table not present in cancer risk table
# Code 01065 in center table not present in cancer risk table
# Code 01063 in center table not present in cancer risk table
# Code 01107 in center table not present in cancer risk table
# Code 01125 in center table not present in cancer risk table
# Code 01073 in center table not present in cancer risk table
# Code 01127 in center table not present in cancer risk table
# Code 01075 in center table not present in cancer risk table
# Code 01057 in center table not present in cancer risk table
# Code 01059 in center table not present in cancer risk table
# Code 01093 in center table not present in cancer risk table
# Code 01133 in center table not present in cancer risk table
# Code 01043 in center table not present in cancer risk table
# Code 01009 in center table not present in cancer risk table
# Code 01115 in center table not present in cancer risk table
# Code 01015 in center table not present in cancer risk table
# Code 01055 in center table not present in cancer risk table
# Code 01095 in center table not present in cancer risk table
# Code 01103 in center table not present in cancer risk table
# Code 01079 in center table not present in cancer risk table
# Code 01033 in center table not present in cancer risk table
# Code 01077 in center table not present in cancer risk table
# Code 01083 in center table not present in cancer risk table
# Code 01089 in center table not present in cancer risk table
# Code 01071 in center table not present in cancer risk table
# Code 01049 in center table not present in cancer risk table
# Code 01019 in center table not present in cancer risk table
# Code 01029 in center table not present in cancer risk table
# Code 01111 in center table not present in cancer risk table
# Code 01017 in center table not present in cancer risk table
# Code 01081 in center table not present in cancer risk table
# Code 01113 in center table not present in cancer risk table
# Code 01005 in center table not present in cancer risk table
# Code 05017 in center table not present in cancer risk table
# Code 05003 in center table not present in cancer risk table
# Code 05115 in center table not present in cancer risk table
# Code 05101 in center table not present in cancer risk table
# Code 05087 in center table not present in cancer risk table
# Code 05047 in center table not present in cancer risk table
# Code 05071 in center table not present in cancer risk table
# Code 05083 in center table not present in cancer risk table
# Code 05149 in center table not present in cancer risk table
# Code 05105 in center table not present in cancer risk table
# Code 05029 in center table not present in cancer risk table
# Code 05045 in center table not present in cancer risk table
# Code 05141 in center table not present in cancer risk table
# Code 05129 in center table not present in cancer risk table
# Code 05137 in center table not present in cancer risk table
# Code 05023 in center table not present in cancer risk table
# Code 05145 in center table not present in cancer risk table
# Code 05063 in center table not present in cancer risk table
# Code 05067 in center table not present in cancer risk table
# Code 05147 in center table not present in cancer risk table
# Code 05123 in center table not present in cancer risk table
# Code 05035 in center table not present in cancer risk table
# Code 05037 in center table not present in cancer risk table
# Code 05111 in center table not present in cancer risk table
# Code 05093 in center table not present in cancer risk table
# Code 05031 in center table not present in cancer risk table
# Code 05065 in center table not present in cancer risk table
# Code 05075 in center table not present in cancer risk table
# Code 05135 in center table not present in cancer risk table
# Code 05055 in center table not present in cancer risk table
# Code 05021 in center table not present in cancer risk table
# Code 05121 in center table not present in cancer risk table
# Code 05049 in center table not present in cancer risk table
# Code 05005 in center table not present in cancer risk table
# Code 05089 in center table not present in cancer risk table
# Code 05009 in center table not present in cancer risk table
# Code 05015 in center table not present in cancer risk table
# Code 05007 in center table not present in cancer risk table
# Code 05143 in center table not present in cancer risk table
# Code 05033 in center table not present in cancer risk table
# Code 05131 in center table not present in cancer risk table
# Code 05127 in center table not present in cancer risk table
# Code 05097 in center table not present in cancer risk table
# Code 05051 in center table not present in cancer risk table
# Code 05125 in center table not present in cancer risk table
# Code 05119 in center table not present in cancer risk table
# Code 05085 in center table not present in cancer risk table
# Code 05117 in center table not present in cancer risk table
# Code 05095 in center table not present in cancer risk table
# Code 05077 in center table not present in cancer risk table
# Code 05107 in center table not present in cancer risk table
# Code 05069 in center table not present in cancer risk table
# Code 05053 in center table not present in cancer risk table
# Code 05059 in center table not present in cancer risk table
# Code 05039 in center table not present in cancer risk table
# Code 05025 in center table not present in cancer risk table
# Code 05079 in center table not present in cancer risk table
# Code 05001 in center table not present in cancer risk table
# Code 05041 in center table not present in cancer risk table
# Code 05043 in center table not present in cancer risk table
# Code 05011 in center table not present in cancer risk table
# Code 05013 in center table not present in cancer risk table
# Code 05103 in center table not present in cancer risk table
# Code 05099 in center table not present in cancer risk table
# Code 05057 in center table not present in cancer risk table
# Code 05019 in center table not present in cancer risk table
# Code 05109 in center table not present in cancer risk table
# Code 05061 in center table not present in cancer risk table
# Code 05113 in center table not present in cancer risk table
# Code 05133 in center table not present in cancer risk table
# Code 05081 in center table not present in cancer risk table
# Code 05091 in center table not present in cancer risk table
# Code 05073 in center table not present in cancer risk table
# Code 05027 in center table not present in cancer risk table
# Code 05139 in center table not present in cancer risk table
# Code 04015 in center table not present in cancer risk table
# Code 04012 in center table not present in cancer risk table
# Code 04003 in center table not present in cancer risk table
# Code 04023 in center table not present in cancer risk table
# Code 04019 in center table not present in cancer risk table
# Code 04011 in center table not present in cancer risk table
# Code 04009 in center table not present in cancer risk table
# Code 04001 in center table not present in cancer risk table
# Code 04017 in center table not present in cancer risk table
# Code 04007 in center table not present in cancer risk table
# Code 04021 in center table not present in cancer risk table
# Code 04027 in center table not present in cancer risk table
# Code 04013 in center table not present in cancer risk table
# Code 04005 in center table not present in cancer risk table
# Code 04025 in center table not present in cancer risk table
# Code 06015 in center table not present in cancer risk table
# Code 06093 in center table not present in cancer risk table
# Code 06025 in center table not present in cancer risk table
# Code 06065 in center table not present in cancer risk table
# Code 06073 in center table not present in cancer risk table
# Code 06059 in center table not present in cancer risk table
# Code 06037 in center table not present in cancer risk table
# Code 06111 in center table not present in cancer risk table
# Code 06083 in center table not present in cancer risk table
# Code 06079 in center table not present in cancer risk table
# Code 06029 in center table not present in cancer risk table
# Code 06071 in center table not present in cancer risk table
# Code 06027 in center table not present in cancer risk table
# Code 06107 in center table not present in cancer risk table
# Code 06031 in center table not present in cancer risk table
# Code 06039 in center table not present in cancer risk table
# Code 06019 in center table not present in cancer risk table
# Code 06053 in center table not present in cancer risk table
# Code 06069 in center table not present in cancer risk table
# Code 06047 in center table not present in cancer risk table
# Code 06087 in center table not present in cancer risk table
# Code 06081 in center table not present in cancer risk table
# Code 06001 in center table not present in cancer risk table
# Code 06085 in center table not present in cancer risk table
# Code 06099 in center table not present in cancer risk table
# Code 06043 in center table not present in cancer risk table
# Code 06109 in center table not present in cancer risk table
# Code 06051 in center table not present in cancer risk table
# Code 06003 in center table not present in cancer risk table
# Code 06009 in center table not present in cancer risk table
# Code 06005 in center table not present in cancer risk table
# Code 06077 in center table not present in cancer risk table
# Code 06013 in center table not present in cancer risk table
# Code 06017 in center table not present in cancer risk table
# Code 06067 in center table not present in cancer risk table
# Code 06095 in center table not present in cancer risk table
# Code 06075 in center table not present in cancer risk table
# Code 06041 in center table not present in cancer risk table
# Code 06055 in center table not present in cancer risk table
# Code 06097 in center table not present in cancer risk table
# Code 06113 in center table not present in cancer risk table
# Code 06061 in center table not present in cancer risk table
# Code 06057 in center table not present in cancer risk table
# Code 06091 in center table not present in cancer risk table
# Code 06115 in center table not present in cancer risk table
# Code 06101 in center table not present in cancer risk table
# Code 06011 in center table not present in cancer risk table
# Code 06033 in center table not present in cancer risk table
# Code 06007 in center table not present in cancer risk table
# Code 06021 in center table not present in cancer risk table
# Code 06063 in center table not present in cancer risk table
# Code 06103 in center table not present in cancer risk table
# Code 06045 in center table not present in cancer risk table
# Code 06023 in center table not present in cancer risk table
# Code 06105 in center table not present in cancer risk table
# Code 06089 in center table not present in cancer risk table
# Code 06035 in center table not present in cancer risk table
# Code 06049 in center table not present in cancer risk table
# Code 08083 in center table not present in cancer risk table
# Code 08067 in center table not present in cancer risk table
# Code 08099 in center table not present in cancer risk table
# Code 08011 in center table not present in cancer risk table
# Code 08061 in center table not present in cancer risk table
# Code 08017 in center table not present in cancer risk table
# Code 08063 in center table not present in cancer risk table
# Code 08125 in center table not present in cancer risk table
# Code 08121 in center table not present in cancer risk table
# Code 08095 in center table not present in cancer risk table
# Code 08115 in center table not present in cancer risk table
# Code 08075 in center table not present in cancer risk table
# Code 08087 in center table not present in cancer risk table
# Code 08009 in center table not present in cancer risk table
# Code 08089 in center table not present in cancer risk table
# Code 08025 in center table not present in cancer risk table
# Code 08073 in center table not present in cancer risk table
# Code 08039 in center table not present in cancer risk table
# Code 08005 in center table not present in cancer risk table
# Code 08123 in center table not present in cancer risk table
# Code 08001 in center table not present in cancer risk table
# Code 08031 in center table not present in cancer risk table
# Code 08035 in center table not present in cancer risk table
# Code 08041 in center table not present in cancer risk table
# Code 08119 in center table not present in cancer risk table
# Code 08101 in center table not present in cancer risk table
# Code 08071 in center table not present in cancer risk table
# Code 08055 in center table not present in cancer risk table
# Code 08023 in center table not present in cancer risk table
# Code 08021 in center table not present in cancer risk table
# Code 08003 in center table not present in cancer risk table
# Code 08105 in center table not present in cancer risk table
# Code 08027 in center table not present in cancer risk table
# Code 08043 in center table not present in cancer risk table
# Code 08109 in center table not present in cancer risk table
# Code 08015 in center table not present in cancer risk table
# Code 08051 in center table not present in cancer risk table
# Code 08097 in center table not present in cancer risk table
# Code 08065 in center table not present in cancer risk table
# Code 08093 in center table not present in cancer risk table
# Code 08059 in center table not present in cancer risk table
# Code 08047 in center table not present in cancer risk table
# Code 08019 in center table not present in cancer risk table
# Code 08117 in center table not present in cancer risk table
# Code 08037 in center table not present in cancer risk table
# Code 08013 in center table not present in cancer risk table
# Code 08049 in center table not present in cancer risk table
# Code 08069 in center table not present in cancer risk table
# Code 08057 in center table not present in cancer risk table
# Code 08107 in center table not present in cancer risk table
# Code 08081 in center table not present in cancer risk table
# Code 08103 in center table not present in cancer risk table
# Code 08045 in center table not present in cancer risk table
# Code 08029 in center table not present in cancer risk table
# Code 08077 in center table not present in cancer risk table
# Code 08085 in center table not present in cancer risk table
# Code 08111 in center table not present in cancer risk table
# Code 08033 in center table not present in cancer risk table
# Code 08113 in center table not present in cancer risk table
# Code 08091 in center table not present in cancer risk table
# Code 08053 in center table not present in cancer risk table
# Code 08079 in center table not present in cancer risk table
# Code 08007 in center table not present in cancer risk table
# Code 08014 in center table not present in cancer risk table
# Code 09003 in center table not present in cancer risk table
# Code 09005 in center table not present in cancer risk table
# Code 09001 in center table not present in cancer risk table
# Code 09009 in center table not present in cancer risk table
# Code 09007 in center table not present in cancer risk table
# Code 09011 in center table not present in cancer risk table
# Code 09013 in center table not present in cancer risk table
# Code 09015 in center table not present in cancer risk table
# Code 10003 in center table not present in cancer risk table
# Code 10005 in center table not present in cancer risk table
# Code 10001 in center table not present in cancer risk table
# Code 12005 in center table not present in cancer risk table
# Code 12063 in center table not present in cancer risk table
# Code 12015 in center table not present in cancer risk table
# Code 12071 in center table not present in cancer risk table
# Code 12051 in center table not present in cancer risk table
# Code 12021 in center table not present in cancer risk table
# Code 12087 in center table not present in cancer risk table
# Code 12086 in center table not present in cancer risk table
# Code 12011 in center table not present in cancer risk table
# Code 12099 in center table not present in cancer risk table
# Code 12115 in center table not present in cancer risk table
# Code 12027 in center table not present in cancer risk table
# Code 12043 in center table not present in cancer risk table
# Code 12085 in center table not present in cancer risk table
# Code 12111 in center table not present in cancer risk table
# Code 12061 in center table not present in cancer risk table
# Code 12093 in center table not present in cancer risk table
# Code 12055 in center table not present in cancer risk table
# Code 12049 in center table not present in cancer risk table
# Code 12081 in center table not present in cancer risk table
# Code 12103 in center table not present in cancer risk table
# Code 12057 in center table not present in cancer risk table
# Code 12053 in center table not present in cancer risk table
# Code 12101 in center table not present in cancer risk table
# Code 12097 in center table not present in cancer risk table
# Code 12105 in center table not present in cancer risk table
# Code 12095 in center table not present in cancer risk table
# Code 12117 in center table not present in cancer risk table
# Code 12069 in center table not present in cancer risk table
# Code 12119 in center table not present in cancer risk table
# Code 12017 in center table not present in cancer risk table
# Code 12075 in center table not present in cancer risk table
# Code 12083 in center table not present in cancer risk table
# Code 12127 in center table not present in cancer risk table
# Code 12009 in center table not present in cancer risk table
# Code 12133 in center table not present in cancer risk table
# Code 12059 in center table not present in cancer risk table
# Code 12131 in center table not present in cancer risk table
# Code 12091 in center table not present in cancer risk table
# Code 12113 in center table not present in cancer risk table
# Code 12033 in center table not present in cancer risk table
# Code 12013 in center table not present in cancer risk table
# Code 12045 in center table not present in cancer risk table
# Code 12037 in center table not present in cancer risk table
# Code 12029 in center table not present in cancer risk table
# Code 12041 in center table not present in cancer risk table
# Code 12001 in center table not present in cancer risk table
# Code 12107 in center table not present in cancer risk table
# Code 12035 in center table not present in cancer risk table
# Code 12109 in center table not present in cancer risk table
# Code 12019 in center table not present in cancer risk table
# Code 12007 in center table not present in cancer risk table
# Code 12125 in center table not present in cancer risk table
# Code 12121 in center table not present in cancer risk table
# Code 12067 in center table not present in cancer risk table
# Code 12123 in center table not present in cancer risk table
# Code 12129 in center table not present in cancer risk table
# Code 12077 in center table not present in cancer risk table
# Code 12039 in center table not present in cancer risk table
# Code 12073 in center table not present in cancer risk table
# Code 12065 in center table not present in cancer risk table
# Code 12079 in center table not present in cancer risk table
# Code 12047 in center table not present in cancer risk table
# Code 12023 in center table not present in cancer risk table
# Code 12003 in center table not present in cancer risk table
# Code 12031 in center table not present in cancer risk table
# Code 12089 in center table not present in cancer risk table
# Code 13241 in center table not present in cancer risk table
# Code 13281 in center table not present in cancer risk table
# Code 13205 in center table not present in cancer risk table
# Code 13007 in center table not present in cancer risk table
# Code 13201 in center table not present in cancer risk table
# Code 13099 in center table not present in cancer risk table
# Code 13253 in center table not present in cancer risk table
# Code 13087 in center table not present in cancer risk table
# Code 13131 in center table not present in cancer risk table
# Code 13275 in center table not present in cancer risk table
# Code 13027 in center table not present in cancer risk table
# Code 13071 in center table not present in cancer risk table
# Code 13075 in center table not present in cancer risk table
# Code 13173 in center table not present in cancer risk table
# Code 13185 in center table not present in cancer risk table
# Code 13101 in center table not present in cancer risk table
# Code 13065 in center table not present in cancer risk table
# Code 13003 in center table not present in cancer risk table
# Code 13019 in center table not present in cancer risk table
# Code 13155 in center table not present in cancer risk table
# Code 13277 in center table not present in cancer risk table
# Code 13321 in center table not present in cancer risk table
# Code 13095 in center table not present in cancer risk table
# Code 13037 in center table not present in cancer risk table
# Code 13061 in center table not present in cancer risk table
# Code 13239 in center table not present in cancer risk table
# Code 13243 in center table not present in cancer risk table
# Code 13273 in center table not present in cancer risk table
# Code 13177 in center table not present in cancer risk table
# Code 13081 in center table not present in cancer risk table
# Code 13287 in center table not present in cancer risk table
# Code 13017 in center table not present in cancer risk table
# Code 13069 in center table not present in cancer risk table
# Code 13005 in center table not present in cancer risk table
# Code 13305 in center table not present in cancer risk table
# Code 13229 in center table not present in cancer risk table
# Code 13025 in center table not present in cancer risk table
# Code 13299 in center table not present in cancer risk table
# Code 13049 in center table not present in cancer risk table
# Code 13039 in center table not present in cancer risk table
# Code 13127 in center table not present in cancer risk table
# Code 13191 in center table not present in cancer risk table
# Code 13149 in center table not present in cancer risk table
# Code 13143 in center table not present in cancer risk table
# Code 13233 in center table not present in cancer risk table
# Code 13115 in center table not present in cancer risk table
# Code 13055 in center table not present in cancer risk table
# Code 13313 in center table not present in cancer risk table
# Code 13047 in center table not present in cancer risk table
# Code 13295 in center table not present in cancer risk table
# Code 13083 in center table not present in cancer risk table
# Code 13183 in center table not present in cancer risk table
# Code 13001 in center table not present in cancer risk table
# Code 13161 in center table not present in cancer risk table
# Code 13259 in center table not present in cancer risk table
# Code 13307 in center table not present in cancer risk table
# Code 13261 in center table not present in cancer risk table
# Code 13315 in center table not present in cancer risk table
# Code 13271 in center table not present in cancer risk table
# Code 13309 in center table not present in cancer risk table
# Code 13091 in center table not present in cancer risk table
# Code 13235 in center table not present in cancer risk table
# Code 13093 in center table not present in cancer risk table
# Code 13193 in center table not present in cancer risk table
# Code 13249 in center table not present in cancer risk table
# Code 13197 in center table not present in cancer risk table
# Code 13053 in center table not present in cancer risk table
# Code 13215 in center table not present in cancer risk table
# Code 13269 in center table not present in cancer risk table
# Code 13263 in center table not present in cancer risk table
# Code 13145 in center table not present in cancer risk table
# Code 13285 in center table not present in cancer risk table
# Code 13045 in center table not present in cancer risk table
# Code 13223 in center table not present in cancer risk table
# Code 13213 in center table not present in cancer risk table
# Code 13129 in center table not present in cancer risk table
# Code 13015 in center table not present in cancer risk table
# Code 13067 in center table not present in cancer risk table
# Code 13097 in center table not present in cancer risk table
# Code 13077 in center table not present in cancer risk table
# Code 13199 in center table not present in cancer risk table
# Code 13231 in center table not present in cancer risk table
# Code 13293 in center table not present in cancer risk table
# Code 13079 in center table not present in cancer risk table
# Code 13225 in center table not present in cancer risk table
# Code 13153 in center table not present in cancer risk table
# Code 13023 in center table not present in cancer risk table
# Code 13175 in center table not present in cancer risk table
# Code 13319 in center table not present in cancer risk table
# Code 13289 in center table not present in cancer risk table
# Code 13021 in center table not present in cancer risk table
# Code 13009 in center table not present in cancer risk table
# Code 13169 in center table not present in cancer risk table
# Code 13207 in center table not present in cancer risk table
# Code 13171 in center table not present in cancer risk table
# Code 13255 in center table not present in cancer risk table
# Code 13113 in center table not present in cancer risk table
# Code 13063 in center table not present in cancer risk table
# Code 13035 in center table not present in cancer risk table
# Code 13151 in center table not present in cancer risk table
# Code 13089 in center table not present in cancer risk table
# Code 13121 in center table not present in cancer risk table
# Code 13057 in center table not present in cancer risk table
# Code 13227 in center table not present in cancer risk table
# Code 13085 in center table not present in cancer risk table
# Code 13117 in center table not present in cancer risk table
# Code 13135 in center table not present in cancer risk table
# Code 13247 in center table not present in cancer risk table
# Code 13159 in center table not present in cancer risk table
# Code 13217 in center table not present in cancer risk table
# Code 13297 in center table not present in cancer risk table
# Code 13013 in center table not present in cancer risk table
# Code 13157 in center table not present in cancer risk table
# Code 13059 in center table not present in cancer risk table
# Code 13219 in center table not present in cancer risk table
# Code 13211 in center table not present in cancer risk table
# Code 13237 in center table not present in cancer risk table
# Code 13141 in center table not present in cancer risk table
# Code 13265 in center table not present in cancer risk table
# Code 13133 in center table not present in cancer risk table
# Code 13221 in center table not present in cancer risk table
# Code 13317 in center table not present in cancer risk table
# Code 13301 in center table not present in cancer risk table
# Code 13189 in center table not present in cancer risk table
# Code 13125 in center table not present in cancer risk table
# Code 13163 in center table not present in cancer risk table
# Code 13303 in center table not present in cancer risk table
# Code 13167 in center table not present in cancer risk table
# Code 13283 in center table not present in cancer risk table
# Code 13209 in center table not present in cancer risk table
# Code 13279 in center table not present in cancer risk table
# Code 13179 in center table not present in cancer risk table
# Code 13109 in center table not present in cancer risk table
# Code 13267 in center table not present in cancer risk table
# Code 13043 in center table not present in cancer risk table
# Code 13107 in center table not present in cancer risk table
# Code 13051 in center table not present in cancer risk table
# Code 13029 in center table not present in cancer risk table
# Code 13031 in center table not present in cancer risk table
# Code 13165 in center table not present in cancer risk table
# Code 13103 in center table not present in cancer risk table
# Code 13251 in center table not present in cancer risk table
# Code 13033 in center table not present in cancer risk table
# Code 13245 in center table not present in cancer risk table
# Code 13073 in center table not present in cancer risk table
# Code 13181 in center table not present in cancer risk table
# Code 13105 in center table not present in cancer risk table
# Code 13195 in center table not present in cancer risk table
# Code 13011 in center table not present in cancer risk table
# Code 13139 in center table not present in cancer risk table
# Code 13187 in center table not present in cancer risk table
# Code 13123 in center table not present in cancer risk table
# Code 13111 in center table not present in cancer risk table
# Code 13291 in center table not present in cancer risk table
# Code 13311 in center table not present in cancer risk table
# Code 13137 in center table not present in cancer risk table
# Code 13147 in center table not present in cancer risk table
# Code 13119 in center table not present in cancer risk table
# Code 13257 in center table not present in cancer risk table
# Code 15007 in center table not present in cancer risk table
# Code 15003 in center table not present in cancer risk table
# Code 15009 in center table not present in cancer risk table
# Code 15001 in center table not present in cancer risk table
# Code 15005 in center table not present in cancer risk table
# Code 19163 in center table not present in cancer risk table
# Code 19045 in center table not present in cancer risk table
# Code 19119 in center table not present in cancer risk table
# Code 19167 in center table not present in cancer risk table
# Code 19149 in center table not present in cancer risk table
# Code 19035 in center table not present in cancer risk table
# Code 19141 in center table not present in cancer risk table
# Code 19143 in center table not present in cancer risk table
# Code 19059 in center table not present in cancer risk table
# Code 19041 in center table not present in cancer risk table
# Code 19021 in center table not present in cancer risk table
# Code 19151 in center table not present in cancer risk table
# Code 19147 in center table not present in cancer risk table
# Code 19063 in center table not present in cancer risk table
# Code 19109 in center table not present in cancer risk table
# Code 19091 in center table not present in cancer risk table
# Code 19193 in center table not present in cancer risk table
# Code 19093 in center table not present in cancer risk table
# Code 19161 in center table not present in cancer risk table
# Code 19025 in center table not present in cancer risk table
# Code 19187 in center table not present in cancer risk table
# Code 19073 in center table not present in cancer risk table
# Code 19027 in center table not present in cancer risk table
# Code 19047 in center table not present in cancer risk table
# Code 19133 in center table not present in cancer risk table
# Code 19085 in center table not present in cancer risk table
# Code 19165 in center table not present in cancer risk table
# Code 19009 in center table not present in cancer risk table
# ...
# Code 51187 in center table not present in cancer risk table
# Code 51157 in center table not present in cancer risk table
# Code 51113 in center table not present in cancer risk table
# Code 51137 in center table not present in cancer risk table
# Code 51109 in center table not present in cancer risk table
# Code 51075 in center table not present in cancer risk table
# Code 51145 in center table not present in cancer risk table
# Code 51007 in center table not present in cancer risk table
# Code 51135 in center table not present in cancer risk table
# Code 51025 in center table not present in cancer risk table
# Code 51053 in center table not present in cancer risk table
# Code 51595 in center table not present in cancer risk table
# Code 51081 in center table not present in cancer risk table
# Code 51735 in center table not present in cancer risk table
# Code 51620 in center table not present in cancer risk table
# Code 51175 in center table not present in cancer risk table
# Code 51650 in center table not present in cancer risk table
# Code 51830 in center table not present in cancer risk table
# Code 51700 in center table not present in cancer risk table
# Code 51740 in center table not present in cancer risk table
# Code 51199 in center table not present in cancer risk table
# Code 51095 in center table not present in cancer risk table
# Code 51181 in center table not present in cancer risk table
# Code 51183 in center table not present in cancer risk table
# Code 51149 in center table not present in cancer risk table
# Code 51730 in center table not present in cancer risk table
# Code 51087 in center table not present in cancer risk table
# Code 51041 in center table not present in cancer risk table
# Code 51036 in center table not present in cancer risk table
# Code 51127 in center table not present in cancer risk table
# Code 51760 in center table not present in cancer risk table
# Code 51630 in center table not present in cancer risk table
# Code 51600 in center table not present in cancer risk table
# Code 51683 in center table not present in cancer risk table
# Code 51107 in center table not present in cancer risk table
# Code 51061 in center table not present in cancer risk table
# Code 51047 in center table not present in cancer risk table
# Code 51177 in center table not present in cancer risk table
# Code 51085 in center table not present in cancer risk table
# Code 51101 in center table not present in cancer risk table
# Code 51097 in center table not present in cancer risk table
# Code 51119 in center table not present in cancer risk table
# Code 51073 in center table not present in cancer risk table
# Code 51103 in center table not present in cancer risk table
# Code 51159 in center table not present in cancer risk table
# Code 51057 in center table not present in cancer risk table
# Code 51033 in center table not present in cancer risk table
# Code 51059 in center table not present in cancer risk table
# Code 51153 in center table not present in cancer risk table
# Code 51179 in center table not present in cancer risk table
# Code 51099 in center table not present in cancer risk table
# Code 51193 in center table not present in cancer risk table
# Code 51133 in center table not present in cancer risk table
# Code 51115 in center table not present in cancer risk table
# Code 51710 in center table not present in cancer risk table
# Code 51093 in center table not present in cancer risk table
# Code 51800 in center table not present in cancer risk table
# Code 51550 in center table not present in cancer risk table
# Code 51810 in center table not present in cancer risk table
# Code 51685 in center table not present in cancer risk table
# Code 50009 in center table not present in cancer risk table
# Code 50019 in center table not present in cancer risk table
# Code 50003 in center table not present in cancer risk table
# Code 50013 in center table not present in cancer risk table
# Code 50023 in center table not present in cancer risk table
# Code 50005 in center table not present in cancer risk table
# Code 50015 in center table not present in cancer risk table
# Code 50011 in center table not present in cancer risk table
# Code 50007 in center table not present in cancer risk table
# Code 50001 in center table not present in cancer risk table
# Code 50021 in center table not present in cancer risk table
# Code 50025 in center table not present in cancer risk table
# Code 50027 in center table not present in cancer risk table
# Code 50017 in center table not present in cancer risk table
# Code 53047 in center table not present in cancer risk table
# Code 53073 in center table not present in cancer risk table
# Code 53069 in center table not present in cancer risk table
# Code 53003 in center table not present in cancer risk table
# Code 53023 in center table not present in cancer risk table
# Code 53013 in center table not present in cancer risk table
# Code 53071 in center table not present in cancer risk table
# Code 53021 in center table not present in cancer risk table
# Code 53075 in center table not present in cancer risk table
# Code 53063 in center table not present in cancer risk table
# Code 53051 in center table not present in cancer risk table
# Code 53065 in center table not present in cancer risk table
# Code 53043 in center table not present in cancer risk table
# Code 53001 in center table not present in cancer risk table
# Code 53025 in center table not present in cancer risk table
# Code 53005 in center table not present in cancer risk table
# Code 53039 in center table not present in cancer risk table
# Code 53011 in center table not present in cancer risk table
# Code 53059 in center table not present in cancer risk table
# Code 53015 in center table not present in cancer risk table
# Code 53049 in center table not present in cancer risk table
# Code 53041 in center table not present in cancer risk table
# Code 53067 in center table not present in cancer risk table
# Code 53053 in center table not present in cancer risk table
# Code 53077 in center table not present in cancer risk table
# Code 53037 in center table not present in cancer risk table
# Code 53017 in center table not present in cancer risk table
# Code 53019 in center table not present in cancer risk table
# Code 53055 in center table not present in cancer risk table
# Code 53029 in center table not present in cancer risk table
# Code 53061 in center table not present in cancer risk table
# Code 53033 in center table not present in cancer risk table
# Code 53035 in center table not present in cancer risk table
# Code 53045 in center table not present in cancer risk table
# Code 53027 in center table not present in cancer risk table
# Code 53031 in center table not present in cancer risk table
# Code 53009 in center table not present in cancer risk table
# Code 53057 in center table not present in cancer risk table
# Code 53007 in center table not present in cancer risk table
# Code 55029 in center table not present in cancer risk table
# Code 55061 in center table not present in cancer risk table
# Code 55093 in center table not present in cancer risk table
# Code 55091 in center table not present in cancer risk table
# Code 55011 in center table not present in cancer risk table
# Code 55121 in center table not present in cancer risk table
# Code 55053 in center table not present in cancer risk table
# Code 55035 in center table not present in cancer risk table
# Code 55019 in center table not present in cancer risk table
# Code 55017 in center table not present in cancer risk table
# Code 55033 in center table not present in cancer risk table
# Code 55109 in center table not present in cancer risk table
# Code 55095 in center table not present in cancer risk table
# Code 55005 in center table not present in cancer risk table
# Code 55107 in center table not present in cancer risk table
# Code 55119 in center table not present in cancer risk table
# Code 55099 in center table not present in cancer risk table
# Code 55113 in center table not present in cancer risk table
# Code 55129 in center table not present in cancer risk table
# Code 55013 in center table not present in cancer risk table
# Code 55031 in center table not present in cancer risk table
# Code 55007 in center table not present in cancer risk table
# Code 55003 in center table not present in cancer risk table
# Code 55051 in center table not present in cancer risk table
# Code 55125 in center table not present in cancer risk table
# Code 55085 in center table not present in cancer risk table
# Code 55069 in center table not present in cancer risk table
# Code 55067 in center table not present in cancer risk table
# Code 55073 in center table not present in cancer risk table
# Code 55141 in center table not present in cancer risk table
# Code 55001 in center table not present in cancer risk table
# Code 55057 in center table not present in cancer risk table
# Code 55081 in center table not present in cancer risk table
# Code 55063 in center table not present in cancer risk table
# Code 55123 in center table not present in cancer risk table
# Code 55111 in center table not present in cancer risk table
# Code 55103 in center table not present in cancer risk table
# Code 55023 in center table not present in cancer risk table
# Code 55049 in center table not present in cancer risk table
# Code 55043 in center table not present in cancer risk table
# Code 55065 in center table not present in cancer risk table
# Code 55045 in center table not present in cancer risk table
# Code 55077 in center table not present in cancer risk table
# Code 55097 in center table not present in cancer risk table
# Code 55135 in center table not present in cancer risk table
# Code 55137 in center table not present in cancer risk table
# Code 55047 in center table not present in cancer risk table
# Code 55021 in center table not present in cancer risk table
# Code 55025 in center table not present in cancer risk table
# Code 55105 in center table not present in cancer risk table
# Code 55059 in center table not present in cancer risk table
# Code 55101 in center table not present in cancer risk table
# Code 55127 in center table not present in cancer risk table
# Code 55027 in center table not present in cancer risk table
# Code 55055 in center table not present in cancer risk table
# Code 55133 in center table not present in cancer risk table
# Code 55079 in center table not present in cancer risk table
# Code 55089 in center table not present in cancer risk table
# Code 55131 in center table not present in cancer risk table
# Code 55139 in center table not present in cancer risk table
# Code 55039 in center table not present in cancer risk table
# Code 55117 in center table not present in cancer risk table
# Code 55015 in center table not present in cancer risk table
# Code 55071 in center table not present in cancer risk table
# Code 55009 in center table not present in cancer risk table
# Code 55087 in center table not present in cancer risk table
# Code 55115 in center table not present in cancer risk table
# Code 55078 in center table not present in cancer risk table
# Code 55083 in center table not present in cancer risk table
# Code 55041 in center table not present in cancer risk table
# Code 55037 in center table not present in cancer risk table
# Code 55075 in center table not present in cancer risk table
# Code 54003 in center table not present in cancer risk table
# Code 54037 in center table not present in cancer risk table
# Code 54011 in center table not present in cancer risk table
# Code 54099 in center table not present in cancer risk table
# Code 54059 in center table not present in cancer risk table
# Code 54045 in center table not present in cancer risk table
# Code 54109 in center table not present in cancer risk table
# Code 54047 in center table not present in cancer risk table
# Code 54055 in center table not present in cancer risk table
# Code 54063 in center table not present in cancer risk table
# Code 54089 in center table not present in cancer risk table
# Code 54081 in center table not present in cancer risk table
# Code 54005 in center table not present in cancer risk table
# Code 54043 in center table not present in cancer risk table
# Code 54079 in center table not present in cancer risk table
# Code 54053 in center table not present in cancer risk table
# Code 54035 in center table not present in cancer risk table
# Code 54039 in center table not present in cancer risk table
# Code 54019 in center table not present in cancer risk table
# Code 54015 in center table not present in cancer risk table
# Code 54087 in center table not present in cancer risk table
# Code 54013 in center table not present in cancer risk table
# Code 54105 in center table not present in cancer risk table
# Code 54107 in center table not present in cancer risk table
# Code 54073 in center table not present in cancer risk table
# Code 54085 in center table not present in cancer risk table
# Code 54021 in center table not present in cancer risk table
# Code 54007 in center table not present in cancer risk table
# Code 54067 in center table not present in cancer risk table
# Code 54025 in center table not present in cancer risk table
# Code 54101 in center table not present in cancer risk table
# Code 54097 in center table not present in cancer risk table
# Code 54041 in center table not present in cancer risk table
# Code 54017 in center table not present in cancer risk table
# Code 54095 in center table not present in cancer risk table
# Code 54033 in center table not present in cancer risk table
# Code 54029 in center table not present in cancer risk table
# Code 54009 in center table not present in cancer risk table
# Code 54069 in center table not present in cancer risk table
# Code 54051 in center table not present in cancer risk table
# Code 54103 in center table not present in cancer risk table
# Code 54049 in center table not present in cancer risk table
# Code 54001 in center table not present in cancer risk table
# Code 54091 in center table not present in cancer risk table
# Code 54061 in center table not present in cancer risk table
# Code 54075 in center table not present in cancer risk table
# Code 54077 in center table not present in cancer risk table
# Code 54083 in center table not present in cancer risk table
# Code 54071 in center table not present in cancer risk table
# Code 54093 in center table not present in cancer risk table
# Code 54023 in center table not present in cancer risk table
# Code 54031 in center table not present in cancer risk table
# Code 54057 in center table not present in cancer risk table
# Code 54027 in center table not present in cancer risk table
# Code 54065 in center table not present in cancer risk table
# Code 56021 in center table not present in cancer risk table
# Code 56015 in center table not present in cancer risk table
# Code 56039 in center table not present in cancer risk table
# Code 56023 in center table not present in cancer risk table
# Code 56041 in center table not present in cancer risk table
# Code 56035 in center table not present in cancer risk table
# Code 56029 in center table not present in cancer risk table
# Code 56037 in center table not present in cancer risk table
# Code 56013 in center table not present in cancer risk table
# Code 56017 in center table not present in cancer risk table
# Code 56043 in center table not present in cancer risk table
# Code 56003 in center table not present in cancer risk table
# Code 56033 in center table not present in cancer risk table
# Code 56019 in center table not present in cancer risk table
# Code 56025 in center table not present in cancer risk table
# Code 56007 in center table not present in cancer risk table
# Code 56001 in center table not present in cancer risk table
# Code 56045 in center table not present in cancer risk table
# Code 56011 in center table not present in cancer risk table
# Code 56005 in center table not present in cancer risk table
# Code 56009 in center table not present in cancer risk table
# Code 56027 in center table not present in cancer risk table
# Code 56031 in center table not present in cancer risk table
# Code 11001 in center table not present in cancer risk table
# Code State_Lines in center table not present in cancer risk table
# Code separator in center table not present in cancer risk table
